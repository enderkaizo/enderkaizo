# %%
f = open("thongtin.csv","r",encoding = "utf8")
header = f.readline() 
data = f.readlines()

L_username = []
L_password = []
L_ten = []
for i in data:
    i = i.strip()
    i = i.split(",")
    L_username.append(i[0])
    L_password.append(i[1])
    L_ten.append(i[2])
    
class ConNguoi:
    def __init__(self,ten):
        self.ten = ten 


from tkinter import *
from PIL import ImageTk,Image   


sc = Tk()
sc.title("demogame")


imgfr7 = ImageTk.PhotoImage(Image.open(r"D:\0anh\anh1.PNG"))
imgfr8 = Image.open(r"D:\0anh\anh2.PNG")
resizefr8 = imgfr8.resize((800,500))
imgfr8 = ImageTk.PhotoImage(resizefr8)



user1 = ConNguoi("Người Chơi")



def changedn1():
    fr1.pack_forget()
    fr2.pack()
def changeql1():
    fr2.pack_forget()
    fr1.pack()
def changedn2():
    fr3.pack_forget()
    fr2.pack()
def changedk1():
    fr1.pack_forget()
    fr3.pack()
def changedk2():
    fr2.pack_forget()
    fr3.pack()
def quaylai():
    fr5.pack_forget()
    fr4.pack()
def bd():
    fr4.pack_forget()
    fr5.pack()
def ttfr6():
    fr5.pack_forget()
    fr6.pack()

def ttfr7():
    fr6.pack_forget()
    lb3_fr7.pack()
    fr7.pack()
def ttfr8():
    fr7.pack_forget()
    lb3_fr7.pack_forget()
    lb4_fr8.pack()
    fr8.pack()
    
def DN():
    username = var1fr2.get()
    password = var2fr2.get()
    if username == "" or password == "":
        lbtb_fr2.config(text = "Vui Lòng Nhập Đầy Đủ Thông Tin")
        return
    elif username not in L_username:
        lbtb_fr2.config(text = "Username Không Tồn Tại")
        return
    vt = L_username.index(username)
    if L_password[vt] != password:
        lbtb_fr2.config(text = "Sai Tên Đăng Nhập Hoặc Mật Khẩu")
        return
    fr2.pack_forget()
    fr4.pack()
    
def DK():
    signupname = var1fr3.get()
    signuppw = var2fr3.get()
    signupcpw = var3fr3.get()
    if signupname == "" or signuppw == "" or signupcpw == "":
        lbtb_fr3.config(text = "Vui Lòng Điền Đầy Đủ Thông Tin")
        return
    elif signupname in L_username:
        lbtb_fr3.config(text = "Username Đã Tồn Tại Vui Lòng Nhập Lại")
        return
    elif signuppw != signupcpw:
        lbtb_fr3.config(text = "Password Không Trùng Vui Lòng Nhập Lại")
        return
    f = open("thongtin.csv","a",encoding = "utf8")
    f.write(signupname+",")
    f.write(signuppw+",Người Chơi\n")
    f.close()
    L_username.append(signupname)
    L_password.append(signuppw)
    var1fr3.set("")
    var2fr3.set("")
    var3fr3.set("")
    fr3.pack_forget()
    fr2.pack()
    lbtb_fr2.config(text = "Mời Bạn Đăng Nhập Lại Để Vào Game")
    
def DX():
    fr4.pack_forget()
    fr2.pack()
    var1fr2.set("")
    var2fr2.set("")
    lbtb_fr2.config(text = "")
def showpassdn():
    if var_cbfr2.get() == 1:
        et2_fr2.config(show="")
    else:
        et2_fr2.config(show="*")
def showpassdk():
    if var_cbfr3.get() ==1:
        et2_fr3.config(show="") 
        et3_fr3.config(show="")
    else:
        et2_fr3.config(show="*") 
        et3_fr3.config(show="*")  
        

fr1 = Frame(sc)

lb1_fr1 = Label(fr1,text = "Chào mừng bạn đã đến với trò chơi của tôi",font = ("Ariel",20),fg = "red",bg="black")
lb2_fr1 = Label(fr1,text = "Nếu đã có tài khoản bấm nút bên trái để đăng nhập còn nếu chưa có vui lòng bấm nút bên phải để đăng ký",font = ("Ariel",20),fg = "red",bg="black")
bt1_fr1 = Button(fr1,text = "Đăng Nhập",font = ("Ariel",20),padx=265,pady=50,fg = "blue",bg = "light green",command = changedn1)
bt2_fr1 = Button(fr1,text = "Đăng Ký",font = ("Ariel",20),padx = 265,pady=50,fg="cyan",bg = "red",command = changedk1)

lb1_fr1.grid(row = 1,column=1)
lb2_fr1.grid(row=2,column=1)
bt1_fr1.grid(row=4,column=1,sticky = W)
bt2_fr1.grid(row=4,column=1,sticky=E)
##fr1.pack()

########
########

fr2 = Frame(sc)

lb3_fr2 = Label(fr2,text = "Vui Lòng Nhập Username và Password Để Đăng Nhập",font = ("Ariel",25))
lb1_fr2 = Label(fr2,text = "Username:",font = ("Ariel",20))
lb2_fr2 = Label(fr2,text = "Password:",font = ("Ariel",20))
var1fr2 = StringVar()
et1_fr2 = Entry(fr2,textvariable = var1fr2,font = ("Ariel",20),width=44)
var2fr2 = StringVar()
et2_fr2 = Entry(fr2,textvariable = var2fr2,font = ("Ariel",20),width = 44,show="*")
bt1_fr2 = Button(fr2,text = "Đăng Nhập",font = ("Ariel",25),command = DN,width= 20)
bt2_fr2 = Button(fr2,text = "Đăng Ký",font = ("Ariel",25),command=changedk2,width=20)
lbtb_fr2 = Label(fr2,text = "",font = ("Ariel",20))
var_cbfr2 = IntVar()
cb1_fr2 = Checkbutton(fr2,text = "Show Password",font =("Ariel",10),variable = var_cbfr2,command = showpassdn) 

lb3_fr2.grid(row=1,column=2)
lb1_fr2.grid(row=2,column=1)
et1_fr2.grid(row=2,column=2)
lb2_fr2.grid(row=3,column=1)
et2_fr2.grid(row=3,column=2)
bt1_fr2.grid(row=5,column=2,sticky=W)
lbtb_fr2.grid(row=4,column=2)
bt2_fr2.grid(row=5,column=2,sticky=E)
cb1_fr2.grid(row=5,column=1)

##########
##########

fr3 = Frame(sc)

lb1_fr3 = Label(fr3,text = "Vui Lòng Nhập Username Và Password Để Đăng Ký",font = ("Ariel",25))
lb2_fr3 = Label(fr3,text = "Username:",font = ("Ariel",20))
var1fr3 = StringVar()
et1_fr3 = Entry(fr3,textvariable = var1fr3,font = ("Ariel",20),width=44)
lb3_fr3 = Label(fr3,text = "Password:",font = ("Ariel",20))
var2fr3 = StringVar()
et2_fr3 = Entry(fr3,textvariable = var2fr3,font = ("Ariel",20),width=44,show="*")
lb4_fr3 = Label(fr3,text = "Password Confirm:",font = ("Ariel",20))
var3fr3 = StringVar()
et3_fr3 = Entry(fr3,textvariable = var3fr3,font = ("Ariel",20),width=44,show="*")
lbtb_fr3 = Label(fr3,text = "",font = ("Ariel",20))
bt1_fr3 = Button(fr3,text = "Đăng Ký",font = ("Ariel",25),width =20,command=DK)
bt2_fr3 = Button(fr3,text = "Đăng Nhập",font = ("Ariel",25),width=20,command=changedn2)
var_cbfr3 = IntVar()
cb1_fr3 = Checkbutton(fr3,text = "Show Password",font =("Ariel",10),variable = var_cbfr3,command = showpassdk)

lb1_fr3.grid(row=1,column=2)
lb2_fr3.grid(row=2,column=1)
et1_fr3.grid(row=2,column=2)
lb3_fr3.grid(row=3,column=1)
et2_fr3.grid(row=3,column=2)
lb4_fr3.grid(row=4,column=1)
et3_fr3.grid(row=4,column=2)
lbtb_fr3.grid(row=5,column=2)
bt1_fr3.grid(row=6,column=2,sticky = W)
bt2_fr3.grid(row=6,column=2,sticky = E)
cb1_fr3.grid(row=6,column=1)

########
########

fr4 = Frame(sc)

bt1_fr4 = Button(fr4,text = "Bắt Đầu",font = ("Ariel",25),bg = "black",fg = "Red",width=11,command=bd)
bt2_fr4 = Button(fr4,text = "Cài Đặt",font = ("Ariel",25),bg="black",fg="Gray",width=11)
bt3_fr4 = Button(fr4,text = "Đăng Xuất",font = ("Ariel",25),bg="black",fg="Gray",width=11,command = DX)
bt4_fr4 = Button(fr4,text = "Thoát Game",font = ("Ariel",25),bg="black",fg="Gray",width=11,command = sc.destroy)

bt1_fr4.grid(row=1,column=1)
bt2_fr4.grid(row=2,column=1)
bt3_fr4.grid(row=3,column=1)
bt4_fr4.grid(row=4,column=1)

#########
#########

fr5 = Frame(sc)

lb1_fr5 = Label(fr5,text = "Xin Chào " + user1.ten,font = ("Ariel",25),bg = "black",width = 23,fg="red")
lb2_fr5 = Label(fr5,text = "Vui Lòng Nhập Tên Dưới Đây:",font = ("Ariel",25),bg = "black",fg="red")
var1fr5 = StringVar()
et1_fr5= Entry(fr5,textvariable=var1fr5,font = ("Ariel",25),bg = "gray",fg="white",width=24)
bt1_fr5= Button(fr5,text = "Tiếp Theo",font = ("Ariel",25),bg = "black",fg="red",width=12,command=ttfr6)
bt2_fr5= Button(fr5,text = "Quay Lại",font = ("Ariel",25),bg = "Green",fg="Blue",width=11,command=quaylai)
user1 = var1fr5.get()
user1 = ConNguoi(user1)


lb1_fr5.grid(row=1,column=2,sticky=W)
lb2_fr5.grid(row=2,column=2,sticky=W)
et1_fr5.grid(row=3,column=2,sticky=W)
bt1_fr5.grid(row=4,column=2,sticky=E)
bt2_fr5.grid(row=4,column=2,sticky=W)
#######
#######

fr6 = Frame(sc)
lb1_fr6 = Label(fr6,text="Trò Chơi Có Nhiều Phân Cảnh Không Phù Hợp Với Người Mắc Bệnh tim ",font = ("Ariel",20),width=60,bg = "black",fg="red")
lb2_fr6 = Label(fr6,text="Hay Các Loại Bệnh Liên Quan Và Cũng không Phù Hợp Với Độ Tuổi Vài Người",font = ("Ariel",20),bg = "black",fg="red")
lb3_fr6 = Label(fr6,text="Người Chơi Hãy Cân Nhắc Kĩ Trước Khi Chơi",font = ("Ariel",20),width=60,bg = "black",fg="red")
lb4_fr6 = Label(fr6,text="Trò Chơi Không Có Thật Và Không Nói Về Cá Nhân Hay Tổ Chức Nào Cả",font = ("Ariel",20),bg = "black",fg="red")
bt1_fr6= Button(fr6,text = "Tiếp Tục",font = ("Ariel",25),bg = "black",fg="red",width=25,command= ttfr7)
bt2_fr6= Button(fr6,text = "Thoát Trò Chơi",font = ("Ariel",25),bg = "Green",fg="Blue",width=25,command=sc.destroy)

lb1_fr6.grid(row=1,column=2)
lb2_fr6.grid(row=2,column=2)
lb3_fr6.grid(row=4,column=2)
lb4_fr6.grid(row=3,column=2)
bt1_fr6.grid(row=5,column=2,sticky=E)
bt2_fr6.grid(row=5,column=2,sticky=W)

######
######
fr7 = Frame(sc)
lb1_fr7= Label(fr7,text = "Bạn Bất Ngờ Tỉnh Dậy Ở Một Căn Phòng Lạ",font = ("Ariel",20),bg = "gray",width=39,fg="black")
lb2_fr7= Label(fr7,text = "Bạn Không Nhớ Gì Cả Ngoài Tên Mình:"+ user1.ten,font = ("Ariel",20),bg = "gray",fg="black")
lb3_fr7= Label(image=imgfr7)
bt1_fr7= Button(fr7,text= "Tiếp Theo",font = ("Ariel",25),bg = "gray",width=15,fg="black",command=ttfr8)
bt2_fr7=Button(fr7,text = "Thoát Trò Chơi",font = ("Ariel",25),bg = "Green",fg="Blue",width=15,command=sc.destroy)

lb1_fr7.grid(row=1,column=1,sticky=W)
lb2_fr7.grid(row=2,column=1)
bt1_fr7.grid(row=3,column=1,sticky=E)
bt2_fr7.grid(row=3,column=1,sticky=W)

#####
#####
fr8 = Frame(sc)
lb1_fr8 = Label(fr8,text="Xin Chào "+ user1.ten +" Có Lẻ Ngươi Không Nhớ Nhưng Khi Còn Sống Ngươi Không Biết Quý Trọng Mạng Mình",font = ("Ariel",20),bg = "gray",fg="red")
lb2_fr8 = Label(fr8,text="Để Cho Thất Tình Lục Dục Chi Phối Người Không Ra Người Vật Không Ra Vật",font = ("Ariel",20),width=80,bg = "gray",fg="red")
lb3_fr8 = Label(fr8,text="Nếu Ngươi Đã Không Cần Thì Hãy Lấy Mạng Sống Ngươi Ra Đặt Cược Chơi Với Ta Vài Trò",width=80,font = ("Ariel",20),bg="gray",fg="red")
lb4_fr8= Label(image=imgfr8)
bt1_fr8= Button(fr8,text= "Tiếp Theo",font = ("Ariel",25),bg = "gray",width=15,fg="black")
bt2_fr8=Button(fr8,text = "Thoát Trò Chơi",font = ("Ariel",25),bg = "Green",fg="Blue",width=15,command=sc.destroy)

lb1_fr8.grid(row=1,column=1)
lb2_fr8.grid(row=2,column=1)
lb3_fr8.grid(row=3,column=1)
bt1_fr8.grid(row=4,column=1,sticky=E)
bt2_fr8.grid(row=4,column=1,sticky=W)
#####
#####

fr9 = Frame(sc)
lb1_fr9 = Label(fr9,text="Bắt Đầu Với Trò Đầu Tiên: Đoán Đồng Xu",font = ("Ariel",20),bg = "gray",fg="black")
lb2_fr9 = Label(fr9,text="Hãy Chọn Mặt Sấp Hoặc Ngữa Nếu Trật Ngươi Sẽ Chết",font = ("Ariel",20),bg = "gray",fg="black")
bt1_fr9 = Button(fr9,text="Sấp",font = ("Ariel",20),bg = "gray",fg="black")
bt2_fr9 = Button(fr9,text="Ngửa",font = ("Ariel",20),bg = "gray",fg="black")


lb1_fr9.grid(row=1,column=1)
lb2_fr9.grid(row=2,column=1)
bt1_fr9.grid(row=3,column=1,sticky=W)
bt2_fr9.grid(row=3,column=1,sticky=E)


fr9.pack()

sc.mainloop()
